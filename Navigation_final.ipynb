# %% [markdown]
# # Navigation
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the first project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893).
#
# ### 1. Start the Environment
#
# We begin by importing some necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from collections import deque
import matplotlib.pyplot as plt
import numpy as np
import random
import torch
from unityagents import UnityEnvironment

# %matplotlib inline

# %%
from agent import Agent

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Banana.app"`
# - **Windows** (x86): `"path/to/Banana_Windows_x86/Banana.exe"`
# - **Windows** (x86_64): `"path/to/Banana_Windows_x86_64/Banana.exe"`
# - **Linux** (x86): `"path/to/Banana_Linux/Banana.x86"`
# - **Linux** (x86_64): `"path/to/Banana_Linux/Banana.x86_64"`
# - **Linux** (x86, headless): `"path/to/Banana_Linux_NoVis/Banana.x86"`
# - **Linux** (x86_64, headless): `"path/to/Banana_Linux_NoVis/Banana.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Banana.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Banana.app")
# ```

# %%
env = UnityEnvironment(file_name="Banana.app")
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
#
# Unity brain name: BananaBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 37
#         Number of stacked Vector Observation: 1
#         Vector Action space type: discrete
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# The simulation contains a single agent that navigates a large environment.  At each time step, it has four actions at its disposal:
# - `0` - walk forward
# - `1` - walk backward
# - `2` - turn left
# - `3` - turn right
#
# The state space has `37` dimensions and contains the agent's velocity, along with ray-based perception of objects around agent's forward direction.  A reward of `+1` is provided for collecting a yellow banana, and a reward of `-1` is provided for collecting a blue banana.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents in the environment
print('Number of agents:', len(env_info.agents))

# number of actions
action_size = brain.vector_action_space_size
print('Number of actions:', action_size)

# examine the state space 
state = env_info.vector_observations[0]
print('States look like:', state)
state_size = len(state)
print('States have length:', state_size)
# Out:
# Number of agents: 1
# Number of actions: 4
# States look like: [1.         0.         0.         0.         0.84408134 0.
#  0.         1.         0.         0.0748472  0.         1.
#  0.         0.         0.25755    1.         0.         0.
#  0.         0.74177343 0.         1.         0.         0.
#  0.25854847 0.         0.         1.         0.         0.09355672
#  0.         1.         0.         0.         0.31969345 0.
#  0.        ]
# States have length: 37

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance. It selects an action (uniformly) at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name] # reset the environment
state = env_info.vector_observations[0]            # get the current state
score = 0                                          # initialize the score
while True:
    action = np.random.randint(action_size)        # select an action
    env_info = env.step(action)[brain_name]        # send the action to the environment
    next_state = env_info.vector_observations[0]   # get the next state
    reward = env_info.rewards[0]                   # get the reward
    done = env_info.local_done[0]                  # see if episode has finished
    score += reward                                # update the score
    state = next_state                             # roll over the state to next time step
    if done:                                       # exit loop if episode finished
        break
    
print("Score: {}".format(score))
# Out:
# Score: 2.0

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
# Deep Q-Learning function

def dqn(n_episodes=2000, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995, train_mode=True, 
        ckpt_path='pth_checkpoints/checkpoint.pth'):
    """Deep Q-Learning.
    
    Params
    ======
        n_episodes (int): maximum number of training episodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon
        eps_decay (float): multiplicative factor (per episode) for decreasing epsilon
        train_mode (bool): if 'True' set environment to training mode
        
    """
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    moving_avgs = []                   # list of moving averages
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        env_info = env.reset(train_mode=train_mode)[brain_name] # reset environment
        state = env_info.vector_observations[0]                 # get current state        
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps)                      # select an action
            env_info = env.step(action)[brain_name]             # send action to environment
            next_state = env_info.vector_observations[0]        # get next state
            reward = env_info.rewards[0]                        # get reward
            done = env_info.local_done[0]                       # see if episode has finished
            agent.step(state, action, reward, next_state, done) # learning step
            state = next_state
            score += reward
            if done:
                break 
        scores_window.append(score)          # save most recent score to window
        scores.append(score)                 # save most recent score to total
        moving_avg = np.mean(scores_window)  # calculate moving average
        moving_avgs.append(moving_avg)       # save most recent moving average
        eps = max(eps_end, eps_decay*eps)    # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, moving_avg), end="")
        if i_episode % 100 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, moving_avg))
        if moving_avg >= 13.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, moving_avg))
            if train_mode:
                torch.save(agent.qnetwork_local.state_dict(), ckpt_path)
            break
    return scores, moving_avgs

# %% [markdown]
# #### Best Performing Agent
# - Standard DQN + replay buffer (no double, no dueling)

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v28_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB+FC64')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 3.35
# Episode 200	Average Score: 9.05
# Episode 300	Average Score: 13.10
#
# Environment solved in 200 episodes!	Average Score: 13.10

# %%
## Test the saved agent

# initialize the agent
agent = Agent(state_size=state_size, action_size=action_size, seed=0)

# load the weights from file
checkpoint = 'pth_checkpoints/v28_checkpoint.pth'
agent.qnetwork_local.load_state_dict(torch.load(checkpoint))

num_episodes = 10
scores = []
for i_episode in range(1,num_episodes+1):
    env_info = env.reset(train_mode=False)[brain_name] # reset the environment
    state = env_info.vector_observations[0]            # get the current state
    score = 0                                          # initialize the score
    while True:
        action = agent.act(state, eps=0)               # select an action
        env_info = env.step(action)[brain_name]        # send the action to the environment
        next_state = env_info.vector_observations[0]   # get the next state
        reward = env_info.rewards[0]                   # get the reward
        done = env_info.local_done[0]                  # see if episode has finished
        #agent.step(state, action, reward, next_state, done) # do the learning

        score += reward                                # update the score
        state = next_state                             # roll over the state to next time step
        if done:                                       # exit loop if episode finished
            scores.append(score)
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores)))
            break

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 1	Average Score: 13.00
# Episode 2	Average Score: 16.00
# Episode 3	Average Score: 15.67
# Episode 4	Average Score: 16.00
# Episode 5	Average Score: 14.40
# Episode 6	Average Score: 12.00
# Episode 7	Average Score: 12.71
# Episode 8	Average Score: 12.25
# Episode 9	Average Score: 12.56
# Episode 10	Average Score: 12.50

# %% [markdown]
# ---
# ### Experiment Summary

# %%
from IPython.display import Image

Image(filename='images/experiment_summary.png', width=800)

# %% [markdown]
# ---
# ### Experiment Results

# %% [markdown]
# #### Agent_v2, FC1=64

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.95, eps_end=0.03, ckpt_path='v8_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='scores')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 3.48
# Episode 200	Average Score: 7.72
# Episode 300	Average Score: 12.54
# Episode 316	Average Score: 13.06
# Environment solved in 216 episodes!	Average Score: 13.06

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='v10_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='scores')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.84
# Episode 200	Average Score: 8.30
# Episode 300	Average Score: 12.31
# Episode 345	Average Score: 13.05
# Environment solved in 245 episodes!	Average Score: 13.05

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.99, eps_end=0.01, ckpt_path='v12_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='scores')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.17
# Episode 200	Average Score: 8.13
# Episode 300	Average Score: 11.20
# Episode 363	Average Score: 13.04
# Environment solved in 263 episodes!	Average Score: 13.04

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='v9_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='scores')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 0.98
# Episode 200	Average Score: 5.95
# Episode 300	Average Score: 11.41
# Episode 332	Average Score: 13.00
# Environment solved in 232 episodes!	Average Score: 13.00

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.99, eps_end=0.01, ckpt_path='v11_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='scores')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 0.97
# Episode 200	Average Score: 6.27
# Episode 300	Average Score: 10.51
# Episode 400	Average Score: 12.62
# Episode 433	Average Score: 13.07
# Environment solved in 333 episodes!	Average Score: 13.07

# %% [markdown]
# #### Agent_v2, FC1=128

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.985, eps_end=0.015, ckpt_path='pth_checkpoints/v17_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN+Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.16
# Episode 200	Average Score: 9.22
# Episode 300	Average Score: 10.91
# Episode 400	Average Score: 11.93
# Episode 417	Average Score: 13.15
# Environment solved in 317 episodes!	Average Score: 13.15

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.985, eps_end=0.015, ckpt_path='pth_checkpoints/v18_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 1.20
# Episode 200	Average Score: 5.73
# Episode 300	Average Score: 9.05
# Episode 397	Average Score: 13.00
# Environment solved in 297 episodes!	Average Score: 13.00

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.985, eps_end=0.015, ckpt_path='pth_checkpoints/v19_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.03
# Episode 200	Average Score: 8.43
# Episode 300	Average Score: 11.14
# Episode 348	Average Score: 13.04
# Environment solved in 248 episodes!	Average Score: 13.04

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.985, eps_end=0.015, ckpt_path='pth_checkpoints/v20_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 0.45
# Episode 200	Average Score: 5.98
# Episode 300	Average Score: 10.02
# Episode 366	Average Score: 13.02
# Environment solved in 266 episodes!	Average Score: 13.02

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.95, eps_end=0.03, ckpt_path='pth_checkpoints/v21_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 1.71
# Episode 200	Average Score: 8.24
# Episode 300	Average Score: 11.04
# Episode 394	Average Score: 13.02
# Environment solved in 294 episodes!	Average Score: 13.02

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.985, eps_end=0.05, ckpt_path='pth_checkpoints/v22_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 1.55
# Episode 200	Average Score: 5.98
# Episode 300	Average Score: 10.89
# Episode 385	Average Score: 13.00
# Environment solved in 285 episodes!	Average Score: 13.00

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.985, eps_end=0.01, ckpt_path='pth_checkpoints/v23_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.02
# Episode 200	Average Score: 7.49
# Episode 300	Average Score: 11.42
# Episode 400	Average Score: 12.56
# Episode 412	Average Score: 13.02
# Environment solved in 312 episodes!	Average Score: 13.02

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v24_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 1.02
# Episode 200	Average Score: 6.01
# Episode 300	Average Score: 9.963
# Episode 400	Average Score: 11.70
# Episode 462	Average Score: 13.01
# Environment solved in 362 episodes!	Average Score: 13.01

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v25_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN+RB')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 1.39
# Episode 200	Average Score: 9.56
# Episode 300	Average Score: 11.45
# Episode 363	Average Score: 13.01
# Environment solved in 263 episodes!	Average Score: 13.01

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v26_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB+Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.37
# Episode 200	Average Score: 7.74
# Episode 300	Average Score: 12.07
# Episode 346	Average Score: 13.00
# Environment solved in 246 episodes!	Average Score: 13.00

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v27_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN+RB+Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 1.47
# Episode 200	Average Score: 8.36
# Episode 300	Average Score: 10.62
# Episode 400	Average Score: 12.57
# Episode 412	Average Score: 13.03
# Environment solved in 312 episodes!	Average Score: 13.03

# %% [markdown]
# #### Agent_v2, FC1=64

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=False)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v29_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN+RB+FC64')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.77
# Episode 200	Average Score: 8.06
# Episode 300	Average Score: 12.30
# Episode 331	Average Score: 13.02
# Environment solved in 231 episodes!	Average Score: 13.02

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=False, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v30_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DQN+RB+FC64+Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 0.76
# Episode 200	Average Score: 7.18
# Episode 300	Average Score: 9.73
# Episode 400	Average Score: 12.06
# Episode 428	Average Score: 13.06
# Environment solved in 328 episodes!	Average Score: 13.06

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.98, eps_end=0.02, ckpt_path='pth_checkpoints/v31_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN+RB+FC64+Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 2.21
# Episode 200	Average Score: 6.06
# Episode 300	Average Score: 9.80
# Episode 374	Average Score: 13.03
# Environment solved in 274 episodes!	Average Score: 13.03

# %%
# run the training loop
agent = Agent(state_size=state_size, action_size=action_size, seed=0, use_double=True, use_dueling=True)
scores, avgs = dqn(n_episodes=600, eps_decay=0.95, eps_end=0.03, ckpt_path='pth_checkpoints/v32_checkpoint.pth')

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores, label='DDQN+RB+FC64+Dueling')
plt.plot(np.arange(len(scores)), avgs, c='r', label='average')
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.legend(loc='upper left');
plt.show()
# Out:
# Episode 100	Average Score: 0.68
# Episode 200	Average Score: 3.79
# Episode 300	Average Score: 8.70
# Episode 400	Average Score: 10.55
# Episode 481	Average Score: 13.01
# Environment solved in 381 episodes!	Average Score: 13.01

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()
